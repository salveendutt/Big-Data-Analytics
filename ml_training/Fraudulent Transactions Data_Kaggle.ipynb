# %% [markdown]
# # ML. Dataset: 'Fraudulent Transactions Data' from Kaggle
#
# This Jupyter notebook is for preliminary training and testing of ML models for fraud detection on dataset 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score

# %%
df = pd.read_csv("../datasets/Fraud.csv")
print(f"rows: {len(df)}")
df.head()
# Out:
# rows: 6362620
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
def preprocess_row_1(row):
    """
    Data preprocessing for a single row in dataset 1 ('Fraudulent Transactions Data' from Kaggle)

    Parameters:
      raw (dict): A single unprocessed row in the dataset

    Returns:
      dict: Preprocessed row with keys: 'type', 'amount', 'oldbalanceOrg', 'newbalanceOrig',
        'isMerchant', 'isFlaggedFraud', 'isFraud' transformed to float/int values only.
    """
    transaction_types = {
        "CASH-IN": 1,
        "CASH-OUT": 2,
        "DEBIT": 3,
        "PAYMENT": 4,
        "TRANSFER": 5,
    }
    return pd.Series({
        "type": transaction_types.get(row["type"], 0),
        "amount": row["amount"],
        "oldbalanceOrg": row["oldbalanceOrg"],
        "newbalanceOrig": row["newbalanceOrig"],
        "isMerchant": row["nameDest"].startswith("M"),
        "isFlaggedFraud": row["isFlaggedFraud"],
        "isFraud": row["isFraud"],
    })

# %%
preprocessed = df.apply(preprocess_row_1, axis=1)
preprocessed.head()
# Out:
#    type    amount  oldbalanceOrg  newbalanceOrig  isMerchant  isFlaggedFraud  \
# 0     4   9839.64       170136.0       160296.36        True               0
# 1     4   1864.28        21249.0        19384.72        True               0
# 2     5    181.00          181.0            0.00       False               0
# 3     0    181.00          181.0            0.00       False               0
# 4     4  11668.14        41554.0        29885.86        True               0
#
#    isFraud
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0

# %%
y = preprocessed['isFraud']
X = preprocessed.drop(columns=['isFraud'])
X_train, X_test, y_train, y_test = train_test_split(X, preprocessed['isFraud'], test_size=0.9999, stratify=y, random_state=2025)

# %%
len(X_train)
# Out:
# 636

# %%
rf = RandomForestClassifier(n_estimators=10, random_state=2025)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
f1_weighted = f1_score(y_test, y_pred, average='weighted')
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(f"Weighted F1 Score: {f1_weighted:.2f}")
# Out:
# Accuracy: 1.00
# Weighted F1 Score: 1.00

# %%
df.to_dict(orient='records')
# Out:
# [{'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9839.64,
#   'nameOrig': 'C1231006815',
#   'oldbalanceOrg': 170136.0,
#   'newbalanceOrig': 160296.36,
#   'nameDest': 'M1979787155',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1864.28,
#   'nameOrig': 'C1666544295',
#   'oldbalanceOrg': 21249.0,
#   'newbalanceOrig': 19384.72,
#   'nameDest': 'M2044282225',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 181.0,
#   'nameOrig': 'C1305486145',
#   'oldbalanceOrg': 181.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C553264065',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 1,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 181.0,
#   'nameOrig': 'C840083671',
#   'oldbalanceOrg': 181.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C38997010',
#   'oldbalanceDest': 21182.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 1,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 11668.14,
#   'nameOrig': 'C2048537720',
#   'oldbalanceOrg': 41554.0,
#   'newbalanceOrig': 29885.86,
#   'nameDest': 'M1230701703',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7817.71,
#   'nameOrig': 'C90045638',
#   'oldbalanceOrg': 53860.0,
#   'newbalanceOrig': 46042.29,
#   'nameDest': 'M573487274',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7107.77,
#   'nameOrig': 'C154988899',
#   'oldbalanceOrg': 183195.0,
#   'newbalanceOrig': 176087.23,
#   'nameDest': 'M408069119',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7861.64,
#   'nameOrig': 'C1912850431',
#   'oldbalanceOrg': 176087.23,
#   'newbalanceOrig': 168225.59,
#   'nameDest': 'M633326333',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4024.36,
#   'nameOrig': 'C1265012928',
#   'oldbalanceOrg': 2671.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1176932104',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 5337.77,
#   'nameOrig': 'C712410124',
#   'oldbalanceOrg': 41720.0,
#   'newbalanceOrig': 36382.23,
#   'nameDest': 'C195600860',
#   'oldbalanceDest': 41898.0,
#   'newbalanceDest': 40348.79,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 9644.94,
#   'nameOrig': 'C1900366749',
#   'oldbalanceOrg': 4465.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C997608398',
#   'oldbalanceDest': 10845.0,
#   'newbalanceDest': 157982.12,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3099.97,
#   'nameOrig': 'C249177573',
#   'oldbalanceOrg': 20771.0,
#   'newbalanceOrig': 17671.03,
#   'nameDest': 'M2096539129',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2560.74,
#   'nameOrig': 'C1648232591',
#   'oldbalanceOrg': 5070.0,
#   'newbalanceOrig': 2509.26,
#   'nameDest': 'M972865270',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 11633.76,
#   'nameOrig': 'C1716932897',
#   'oldbalanceOrg': 10127.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M801569151',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4098.78,
#   'nameOrig': 'C1026483832',
#   'oldbalanceOrg': 503264.0,
#   'newbalanceOrig': 499165.22,
#   'nameDest': 'M1635378213',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 229133.94,
#   'nameOrig': 'C905080434',
#   'oldbalanceOrg': 15325.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C476402209',
#   'oldbalanceDest': 5083.0,
#   'newbalanceDest': 51513.44,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1563.82,
#   'nameOrig': 'C761750706',
#   'oldbalanceOrg': 450.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1731217984',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1157.86,
#   'nameOrig': 'C1237762639',
#   'oldbalanceOrg': 21156.0,
#   'newbalanceOrig': 19998.14,
#   'nameDest': 'M1877062907',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 671.64,
#   'nameOrig': 'C2033524545',
#   'oldbalanceOrg': 15123.0,
#   'newbalanceOrig': 14451.36,
#   'nameDest': 'M473053293',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 215310.3,
#   'nameOrig': 'C1670993182',
#   'oldbalanceOrg': 705.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1100439041',
#   'oldbalanceDest': 22425.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1373.43,
#   'nameOrig': 'C20804602',
#   'oldbalanceOrg': 13854.0,
#   'newbalanceOrig': 12480.57,
#   'nameDest': 'M1344519051',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 9302.79,
#   'nameOrig': 'C1566511282',
#   'oldbalanceOrg': 11299.0,
#   'newbalanceOrig': 1996.21,
#   'nameDest': 'C1973538135',
#   'oldbalanceDest': 29832.0,
#   'newbalanceDest': 16896.7,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 1065.41,
#   'nameOrig': 'C1959239586',
#   'oldbalanceOrg': 1817.0,
#   'newbalanceOrig': 751.59,
#   'nameDest': 'C515132998',
#   'oldbalanceDest': 10330.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3876.41,
#   'nameOrig': 'C504336483',
#   'oldbalanceOrg': 67852.0,
#   'newbalanceOrig': 63975.59,
#   'nameDest': 'M1404932042',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 311685.89,
#   'nameOrig': 'C1984094095',
#   'oldbalanceOrg': 10835.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C932583850',
#   'oldbalanceDest': 6267.0,
#   'newbalanceDest': 2719172.89,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6061.13,
#   'nameOrig': 'C1043358826',
#   'oldbalanceOrg': 443.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1558079303',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9478.39,
#   'nameOrig': 'C1671590089',
#   'oldbalanceOrg': 116494.0,
#   'newbalanceOrig': 107015.61,
#   'nameDest': 'M58488213',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8009.09,
#   'nameOrig': 'C1053967012',
#   'oldbalanceOrg': 10968.0,
#   'newbalanceOrig': 2958.91,
#   'nameDest': 'M295304806',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8901.99,
#   'nameOrig': 'C1632497828',
#   'oldbalanceOrg': 2958.91,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M33419717',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9920.52,
#   'nameOrig': 'C764826684',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1940055334',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3448.92,
#   'nameOrig': 'C2103763750',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M335107734',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4206.84,
#   'nameOrig': 'C215078753',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1757317128',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5885.56,
#   'nameOrig': 'C840514538',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1804441305',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5307.88,
#   'nameOrig': 'C1768242710',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1971783162',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5031.22,
#   'nameOrig': 'C247113419',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M151442075',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 24213.67,
#   'nameOrig': 'C1238616099',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M70695990',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8603.42,
#   'nameOrig': 'C1608633989',
#   'oldbalanceOrg': 253.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1615617512',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2791.42,
#   'nameOrig': 'C923341586',
#   'oldbalanceOrg': 300481.0,
#   'newbalanceOrig': 297689.58,
#   'nameDest': 'M107994825',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7413.54,
#   'nameOrig': 'C1470868839',
#   'oldbalanceOrg': 297689.58,
#   'newbalanceOrig': 290276.03,
#   'nameDest': 'M1426725223',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3295.19,
#   'nameOrig': 'C711197015',
#   'oldbalanceOrg': 233633.0,
#   'newbalanceOrig': 230337.81,
#   'nameDest': 'M1384454980',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1684.81,
#   'nameOrig': 'C1481594086',
#   'oldbalanceOrg': 297.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1569435561',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 5758.59,
#   'nameOrig': 'C1466917878',
#   'oldbalanceOrg': 32604.0,
#   'newbalanceOrig': 26845.41,
#   'nameDest': 'C1297685781',
#   'oldbalanceDest': 209699.0,
#   'newbalanceDest': 16997.22,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 110414.71,
#   'nameOrig': 'C768216420',
#   'oldbalanceOrg': 26845.41,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1509514333',
#   'oldbalanceDest': 288800.0,
#   'newbalanceDest': 2415.16,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7823.46,
#   'nameOrig': 'C260084831',
#   'oldbalanceOrg': 998.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M267814113',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5086.48,
#   'nameOrig': 'C598357562',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1593224710',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5281.48,
#   'nameOrig': 'C1440738283',
#   'oldbalanceOrg': 152019.0,
#   'newbalanceOrig': 146737.52,
#   'nameDest': 'M1849015357',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 13875.98,
#   'nameOrig': 'C484199463',
#   'oldbalanceOrg': 15818.0,
#   'newbalanceOrig': 1942.02,
#   'nameDest': 'M2008106788',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 56953.9,
#   'nameOrig': 'C1570470538',
#   'oldbalanceOrg': 1942.02,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C824009085',
#   'oldbalanceDest': 70253.0,
#   'newbalanceDest': 64106.18,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 5346.89,
#   'nameOrig': 'C512549200',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C248609774',
#   'oldbalanceDest': 652637.0,
#   'newbalanceDest': 6453430.91,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2204.04,
#   'nameOrig': 'C1615801298',
#   'oldbalanceOrg': 586.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M490391704',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2641.47,
#   'nameOrig': 'C460570271',
#   'oldbalanceOrg': 23053.0,
#   'newbalanceOrig': 20411.53,
#   'nameDest': 'M1653361344',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 23261.3,
#   'nameOrig': 'C2072313080',
#   'oldbalanceOrg': 20411.53,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C2001112025',
#   'oldbalanceDest': 25742.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2330.64,
#   'nameOrig': 'C816944408',
#   'oldbalanceOrg': 203543.0,
#   'newbalanceOrig': 201212.36,
#   'nameDest': 'M909132503',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1614.64,
#   'nameOrig': 'C912966811',
#   'oldbalanceOrg': 41276.0,
#   'newbalanceOrig': 39661.36,
#   'nameDest': 'M1792384402',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9164.71,
#   'nameOrig': 'C1458621573',
#   'oldbalanceOrg': 47235.77,
#   'newbalanceOrig': 38071.06,
#   'nameDest': 'M1658980982',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2970.97,
#   'nameOrig': 'C46941357',
#   'oldbalanceOrg': 38071.06,
#   'newbalanceOrig': 35100.09,
#   'nameDest': 'M1152606315',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 38.66,
#   'nameOrig': 'C343345308',
#   'oldbalanceOrg': 16174.0,
#   'newbalanceOrig': 16135.34,
#   'nameDest': 'M1714688478',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2252.44,
#   'nameOrig': 'C104716441',
#   'oldbalanceOrg': 1627.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1506951181',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 62610.8,
#   'nameOrig': 'C1976401987',
#   'oldbalanceOrg': 79114.0,
#   'newbalanceOrig': 16503.2,
#   'nameDest': 'C1937962514',
#   'oldbalanceDest': 517.0,
#   'newbalanceDest': 8383.29,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 5529.13,
#   'nameOrig': 'C867288517',
#   'oldbalanceOrg': 8547.0,
#   'newbalanceOrig': 3017.87,
#   'nameDest': 'C242131142',
#   'oldbalanceDest': 10206.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 82940.31,
#   'nameOrig': 'C1528834618',
#   'oldbalanceOrg': 3017.87,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C476800120',
#   'oldbalanceDest': 132372.0,
#   'newbalanceDest': 49864.36,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 4510.22,
#   'nameOrig': 'C280615803',
#   'oldbalanceOrg': 10256.0,
#   'newbalanceOrig': 5745.78,
#   'nameDest': 'C1254526270',
#   'oldbalanceDest': 10697.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 8727.74,
#   'nameOrig': 'C166694583',
#   'oldbalanceOrg': 882770.0,
#   'newbalanceOrig': 874042.26,
#   'nameDest': 'C1129670968',
#   'oldbalanceDest': 12636.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2599.46,
#   'nameOrig': 'C885910946',
#   'oldbalanceOrg': 874042.26,
#   'newbalanceOrig': 871442.79,
#   'nameDest': 'M1860591867',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 4874.49,
#   'nameOrig': 'C811207775',
#   'oldbalanceOrg': 153.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1971489295',
#   'oldbalanceDest': 253104.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6440.78,
#   'nameOrig': 'C1161148117',
#   'oldbalanceOrg': 2192.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M516875052',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4910.14,
#   'nameOrig': 'C1131592118',
#   'oldbalanceOrg': 41551.0,
#   'newbalanceOrig': 36640.86,
#   'nameDest': 'M589987187',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6444.64,
#   'nameOrig': 'C1262609629',
#   'oldbalanceOrg': 12019.0,
#   'newbalanceOrig': 5574.36,
#   'nameDest': 'M587180314',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 5149.66,
#   'nameOrig': 'C1955990522',
#   'oldbalanceOrg': 4782.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1330106945',
#   'oldbalanceDest': 52752.0,
#   'newbalanceDest': 24044.18,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7292.16,
#   'nameOrig': 'C69673470',
#   'oldbalanceOrg': 216827.0,
#   'newbalanceOrig': 209534.84,
#   'nameDest': 'M1082411691',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 47458.86,
#   'nameOrig': 'C527211736',
#   'oldbalanceOrg': 209534.84,
#   'newbalanceOrig': 162075.98,
#   'nameDest': 'C2096057945',
#   'oldbalanceDest': 52120.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 136872.92,
#   'nameOrig': 'C1533123860',
#   'oldbalanceOrg': 162075.98,
#   'newbalanceOrig': 25203.05,
#   'nameDest': 'C766572210',
#   'oldbalanceDest': 217806.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 94253.33,
#   'nameOrig': 'C1718906711',
#   'oldbalanceOrg': 25203.05,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C977993101',
#   'oldbalanceDest': 99773.0,
#   'newbalanceDest': 965870.05,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2998.04,
#   'nameOrig': 'C71802912',
#   'oldbalanceOrg': 12030.0,
#   'newbalanceOrig': 9031.96,
#   'nameDest': 'M2134271532',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3454.08,
#   'nameOrig': 'C686349795',
#   'oldbalanceOrg': 9031.96,
#   'newbalanceOrig': 5577.88,
#   'nameDest': 'M1831010686',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4316.2,
#   'nameOrig': 'C1423768154',
#   'oldbalanceOrg': 10999.0,
#   'newbalanceOrig': 6682.8,
#   'nameDest': 'M404222443',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2131.84,
#   'nameOrig': 'C1987977423',
#   'oldbalanceOrg': 224.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M61073295',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 12986.61,
#   'nameOrig': 'C807322507',
#   'oldbalanceOrg': 23350.0,
#   'newbalanceOrig': 10363.39,
#   'nameDest': 'M396485834',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 42712.39,
#   'nameOrig': 'C283039401',
#   'oldbalanceOrg': 10363.39,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1330106945',
#   'oldbalanceDest': 57901.66,
#   'newbalanceDest': 24044.18,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 77957.68,
#   'nameOrig': 'C207471778',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1761291320',
#   'oldbalanceDest': 94900.0,
#   'newbalanceDest': 22233.65,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 17231.46,
#   'nameOrig': 'C1243171897',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C783286238',
#   'oldbalanceDest': 24672.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 78766.03,
#   'nameOrig': 'C1376151044',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1749186397',
#   'oldbalanceDest': 103772.0,
#   'newbalanceDest': 277515.05,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 224606.64,
#   'nameOrig': 'C873175411',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C766572210',
#   'oldbalanceDest': 354678.92,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 125872.53,
#   'nameOrig': 'C1443967876',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C392292416',
#   'oldbalanceDest': 348512.0,
#   'newbalanceDest': 3420103.09,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 379856.23,
#   'nameOrig': 'C1449772539',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 900180.0,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 1505626.01,
#   'nameOrig': 'C926859124',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C665576141',
#   'oldbalanceDest': 29031.0,
#   'newbalanceDest': 5515763.34,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 554026.99,
#   'nameOrig': 'C1603696865',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C766572210',
#   'oldbalanceDest': 579285.56,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 147543.1,
#   'nameOrig': 'C12905860',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1359044626',
#   'oldbalanceDest': 223220.0,
#   'newbalanceDest': 16518.36,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 761507.39,
#   'nameOrig': 'C412788346',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 1280036.23,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 1429051.47,
#   'nameOrig': 'C1520267010',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 2041543.62,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 358831.92,
#   'nameOrig': 'C908084672',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C392292416',
#   'oldbalanceDest': 474384.53,
#   'newbalanceDest': 3420103.09,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 367768.4,
#   'nameOrig': 'C288306765',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1359044626',
#   'oldbalanceDest': 370763.1,
#   'newbalanceDest': 16518.36,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 209711.11,
#   'nameOrig': 'C1556867940',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1509514333',
#   'oldbalanceDest': 399214.71,
#   'newbalanceDest': 2415.16,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 583848.46,
#   'nameOrig': 'C1839168128',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1286084959',
#   'oldbalanceDest': 667778.0,
#   'newbalanceDest': 2107778.11,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 1724887.05,
#   'nameOrig': 'C1495608502',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 3470595.1,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 710544.77,
#   'nameOrig': 'C835773569',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1359044626',
#   'oldbalanceDest': 738531.5,
#   'newbalanceDest': 16518.36,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 581294.26,
#   'nameOrig': 'C843299092',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 5195482.15,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 11996.58,
#   'nameOrig': 'C605982374',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1225616405',
#   'oldbalanceDest': 40255.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2875.1,
#   'nameOrig': 'C1412322831',
#   'oldbalanceOrg': 15443.0,
#   'newbalanceOrig': 12567.9,
#   'nameDest': 'M1651262695',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8586.98,
#   'nameOrig': 'C1305004711',
#   'oldbalanceOrg': 3763.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M494077446',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 871.75,
#   'nameOrig': 'C1003206025',
#   'oldbalanceOrg': 19869.0,
#   'newbalanceOrig': 18997.25,
#   'nameDest': 'M989889899',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1035.36,
#   'nameOrig': 'C806813022',
#   'oldbalanceOrg': 71636.0,
#   'newbalanceOrig': 70600.64,
#   'nameDest': 'M902860396',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1063.53,
#   'nameOrig': 'C1406206626',
#   'oldbalanceOrg': 83084.0,
#   'newbalanceOrig': 82020.47,
#   'nameDest': 'M1816522350',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1019.9,
#   'nameOrig': 'C1799230133',
#   'oldbalanceOrg': 204237.0,
#   'newbalanceOrig': 203217.1,
#   'nameDest': 'M1521238608',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4059.38,
#   'nameOrig': 'C20156341',
#   'oldbalanceOrg': 26304.0,
#   'newbalanceOrig': 22244.62,
#   'nameDest': 'M1111897955',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1876.44,
#   'nameOrig': 'C1509309988',
#   'oldbalanceOrg': 182.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1643141512',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 28404.6,
#   'nameOrig': 'C2091072548',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1282788025',
#   'oldbalanceDest': 51744.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 75405.1,
#   'nameOrig': 'C263053820',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1870252780',
#   'oldbalanceDest': 104209.0,
#   'newbalanceDest': 46462.23,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 50101.88,
#   'nameOrig': 'C1740826931',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C97730845',
#   'oldbalanceDest': 67684.0,
#   'newbalanceDest': 9940339.29,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 14121.82,
#   'nameOrig': 'C69062746',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C100555887',
#   'oldbalanceDest': 52679.0,
#   'newbalanceDest': 10963.66,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 78292.91,
#   'nameOrig': 'C1631227617',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1983747920',
#   'oldbalanceDest': 121112.0,
#   'newbalanceDest': 95508.95,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 176149.9,
#   'nameOrig': 'C24650043',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C736709391',
#   'oldbalanceDest': 259813.0,
#   'newbalanceDest': 46820.71,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 212228.35,
#   'nameOrig': 'C1896074070',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C401424608',
#   'oldbalanceDest': 429747.0,
#   'newbalanceDest': 1178808.14,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 85423.63,
#   'nameOrig': 'C460741164',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 5776776.41,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 11648.5,
#   'nameOrig': 'C781091365',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C985934102',
#   'oldbalanceDest': 260976.0,
#   'newbalanceDest': 971418.91,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6165.58,
#   'nameOrig': 'C1858015030',
#   'oldbalanceOrg': 20925.0,
#   'newbalanceOrig': 14759.42,
#   'nameDest': 'M25764044',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3705.83,
#   'nameOrig': 'C671596011',
#   'oldbalanceOrg': 41903.46,
#   'newbalanceOrig': 38197.63,
#   'nameDest': 'M1925352804',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 419801.4,
#   'nameOrig': 'C1687354037',
#   'oldbalanceOrg': 38197.63,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C33524623',
#   'oldbalanceDest': 499962.0,
#   'newbalanceDest': 1517262.16,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 335416.51,
#   'nameOrig': 'C743778731',
#   'oldbalanceOrg': 144478.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C575335780',
#   'oldbalanceDest': 295.0,
#   'newbalanceDest': 52415.15,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3372.29,
#   'nameOrig': 'C967323951',
#   'oldbalanceOrg': 41398.0,
#   'newbalanceOrig': 38025.71,
#   'nameDest': 'M1600594643',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 661.43,
#   'nameOrig': 'C743648472',
#   'oldbalanceOrg': 14078.0,
#   'newbalanceOrig': 13416.57,
#   'nameDest': 'M692998280',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 864.68,
#   'nameOrig': 'C1368862151',
#   'oldbalanceOrg': 69836.0,
#   'newbalanceOrig': 68971.32,
#   'nameDest': 'C20671747',
#   'oldbalanceDest': 12040.0,
#   'newbalanceDest': 43691.09,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1203.44,
#   'nameOrig': 'C922807452',
#   'oldbalanceOrg': 29941.0,
#   'newbalanceOrig': 28737.56,
#   'nameDest': 'M33563464',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 330757.04,
#   'nameOrig': 'C1494346128',
#   'oldbalanceOrg': 103657.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C564160838',
#   'oldbalanceDest': 79676.0,
#   'newbalanceDest': 1254956.07,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1915.43,
#   'nameOrig': 'C822087264',
#   'oldbalanceOrg': 11450.0,
#   'newbalanceOrig': 9534.57,
#   'nameDest': 'M30699728',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8.73,
#   'nameOrig': 'C38603201',
#   'oldbalanceOrg': 81313.0,
#   'newbalanceOrig': 81304.27,
#   'nameDest': 'M1422273905',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 3058.8,
#   'nameOrig': 'C1694784135',
#   'oldbalanceOrg': 18138.0,
#   'newbalanceOrig': 15079.2,
#   'nameDest': 'C801197928',
#   'oldbalanceDest': 11054.0,
#   'newbalanceDest': 8917.54,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5154.97,
#   'nameOrig': 'C1207231495',
#   'oldbalanceOrg': 9476.0,
#   'newbalanceOrig': 4321.03,
#   'nameDest': 'M756936249',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5213.25,
#   'nameOrig': 'C1221981006',
#   'oldbalanceOrg': 36380.0,
#   'newbalanceOrig': 31166.75,
#   'nameDest': 'M264394929',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5392.75,
#   'nameOrig': 'C1878413714',
#   'oldbalanceOrg': 50757.0,
#   'newbalanceOrig': 45364.25,
#   'nameDest': 'M769132147',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 25.12,
#   'nameOrig': 'C1257299717',
#   'oldbalanceOrg': 61663.0,
#   'newbalanceOrig': 61637.88,
#   'nameDest': 'M1474957626',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 17150.89,
#   'nameOrig': 'C181252244',
#   'oldbalanceOrg': 61637.88,
#   'newbalanceOrig': 44486.99,
#   'nameDest': 'M1733022752',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 679502.24,
#   'nameOrig': 'C722417467',
#   'oldbalanceOrg': 290.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C451111351',
#   'oldbalanceDest': 171866.0,
#   'newbalanceDest': 3940085.21,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 177652.91,
#   'nameOrig': 'C753631393',
#   'oldbalanceOrg': 23720.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C716157500',
#   'oldbalanceDest': 55.0,
#   'newbalanceDest': 4894.45,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5443.26,
#   'nameOrig': 'C1262869688',
#   'oldbalanceOrg': 236997.0,
#   'newbalanceOrig': 231553.74,
#   'nameDest': 'M1914108708',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 244.87,
#   'nameOrig': 'C544386226',
#   'oldbalanceOrg': 257978.49,
#   'newbalanceOrig': 257733.62,
#   'nameDest': 'M1357700757',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8281.57,
#   'nameOrig': 'C900298796',
#   'oldbalanceOrg': 257733.62,
#   'newbalanceOrig': 249452.05,
#   'nameDest': 'M1889757798',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1175.59,
#   'nameOrig': 'C1166106620',
#   'oldbalanceOrg': 20509.0,
#   'newbalanceOrig': 19333.41,
#   'nameDest': 'M1932470703',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1097.74,
#   'nameOrig': 'C221861886',
#   'oldbalanceOrg': 24866.0,
#   'newbalanceOrig': 23768.26,
#   'nameDest': 'M1713568869',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 184986.8,
#   'nameOrig': 'C697508322',
#   'oldbalanceOrg': 39588.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1688019098',
#   'oldbalanceDest': 52340.0,
#   'newbalanceDest': 97263.78,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1718.29,
#   'nameOrig': 'C603658030',
#   'oldbalanceOrg': 117811.0,
#   'newbalanceOrig': 116092.71,
#   'nameDest': 'M1689924104',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3671.32,
#   'nameOrig': 'C361380654',
#   'oldbalanceOrg': 100094.0,
#   'newbalanceOrig': 96422.68,
#   'nameDest': 'M631673932',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 3580.26,
#   'nameOrig': 'C1579132337',
#   'oldbalanceOrg': 2565.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1321640594',
#   'oldbalanceDest': 21185.0,
#   'newbalanceDest': 18910.85,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8550.9,
#   'nameOrig': 'C1795225096',
#   'oldbalanceOrg': 40060.0,
#   'newbalanceOrig': 31509.1,
#   'nameDest': 'M790094605',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9753.55,
#   'nameOrig': 'C1048712791',
#   'oldbalanceOrg': 60829.0,
#   'newbalanceOrig': 51075.45,
#   'nameDest': 'M487792155',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3026.98,
#   'nameOrig': 'C1909398279',
#   'oldbalanceOrg': 31139.0,
#   'newbalanceOrig': 28112.02,
#   'nameDest': 'M1632670136',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 467177.03,
#   'nameOrig': 'C1338905451',
#   'oldbalanceOrg': 28112.02,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1170794006',
#   'oldbalanceDest': 975121.0,
#   'newbalanceDest': 22190.99,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 3875.99,
#   'nameOrig': 'C1252540239',
#   'oldbalanceOrg': 259138.0,
#   'newbalanceOrig': 255262.01,
#   'nameDest': 'C1509514333',
#   'oldbalanceDest': 608925.82,
#   'newbalanceDest': 2415.16,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2148.89,
#   'nameOrig': 'C1136005694',
#   'oldbalanceOrg': 31213.0,
#   'newbalanceOrig': 29064.11,
#   'nameDest': 'M638486177',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 466.97,
#   'nameOrig': 'C426019904',
#   'oldbalanceOrg': 80030.0,
#   'newbalanceOrig': 79563.03,
#   'nameDest': 'M314411620',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 154139.72,
#   'nameOrig': 'C1642679791',
#   'oldbalanceOrg': 79563.03,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C564160838',
#   'oldbalanceDest': 410433.04,
#   'newbalanceDest': 1254956.07,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 82685.93,
#   'nameOrig': 'C855700733',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C392292416',
#   'oldbalanceDest': 833216.44,
#   'newbalanceDest': 3420103.09,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 83857.23,
#   'nameOrig': 'C247162961',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1297685781',
#   'oldbalanceDest': 215457.59,
#   'newbalanceDest': 16997.22,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 99109.77,
#   'nameOrig': 'C1890266440',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1297685781',
#   'oldbalanceDest': 299314.82,
#   'newbalanceDest': 16997.22,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 187726.67,
#   'nameOrig': 'C1527152775',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C747464370',
#   'oldbalanceDest': 190573.0,
#   'newbalanceDest': 1567434.81,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 281339.92,
#   'nameOrig': 'C1863655430',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1509514333',
#   'oldbalanceDest': 612801.81,
#   'newbalanceDest': 2415.16,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 186447.51,
#   'nameOrig': 'C976827477',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 5862200.03,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 81029.86,
#   'nameOrig': 'C324112183',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C288665596',
#   'oldbalanceDest': 105343.0,
#   'newbalanceDest': 8496.61,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 139054.95,
#   'nameOrig': 'C2092709730',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1749186397',
#   'oldbalanceDest': 182538.03,
#   'newbalanceDest': 277515.05,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 154716.2,
#   'nameOrig': 'C980364771',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C453211571',
#   'oldbalanceDest': 187433.0,
#   'newbalanceDest': 3461666.05,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 53631.83,
#   'nameOrig': 'C1233595751',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C757108857',
#   'oldbalanceDest': 83244.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 289645.52,
#   'nameOrig': 'C1446001495',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1023714065',
#   'oldbalanceDest': 871442.79,
#   'newbalanceDest': 1412484.09,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 267148.82,
#   'nameOrig': 'C1261044180',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C401424608',
#   'oldbalanceDest': 641975.35,
#   'newbalanceDest': 1178808.14,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 47913.58,
#   'nameOrig': 'C141110631',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C240650537',
#   'oldbalanceDest': 51304.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 193605.38,
#   'nameOrig': 'C2029372696',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1971489295',
#   'oldbalanceDest': 249452.05,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 344464.4,
#   'nameOrig': 'C793293778',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C766572210',
#   'oldbalanceDest': 1133312.56,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 169409.87,
#   'nameOrig': 'C888611662',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C401424608',
#   'oldbalanceDest': 909124.16,
#   'newbalanceDest': 1178808.14,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 25793.74,
#   'nameOrig': 'C1966355106',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C476800120',
#   'oldbalanceDest': 215312.31,
#   'newbalanceDest': 49864.36,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 114712.48,
#   'nameOrig': 'C599782425',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1209271652',
#   'oldbalanceDest': 145400.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 89038.75,
#   'nameOrig': 'C1233327519',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C2083562754',
#   'oldbalanceDest': 189808.0,
#   'newbalanceDest': 1186556.81,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 1341.58,
#   'nameOrig': 'C1155769010',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C557041912',
#   'oldbalanceDest': 80341.0,
#   'newbalanceDest': 557537.26,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 44443.08,
#   'nameOrig': 'C269892014',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 6048647.54,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 34729.64,
#   'nameOrig': 'C1280641161',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1435804085',
#   'oldbalanceDest': 44853.0,
#   'newbalanceDest': 96.88,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 105979.34,
#   'nameOrig': 'C489411441',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C736709391',
#   'oldbalanceDest': 435962.9,
#   'newbalanceDest': 46820.71,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 57794.61,
#   'nameOrig': 'C1141113940',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C240650537',
#   'oldbalanceDest': 99217.58,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 15918.79,
#   'nameOrig': 'C1711185459',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1854778591',
#   'oldbalanceDest': 24553.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 19162.08,
#   'nameOrig': 'C25936709',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C885951223',
#   'oldbalanceDest': 60169.0,
#   'newbalanceDest': 215851.28,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 220691.42,
#   'nameOrig': 'C1123559518',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1590550415',
#   'oldbalanceDest': 6093090.62,
#   'newbalanceDest': 19169204.93,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 9536.54,
#   'nameOrig': 'C649769713',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1060830840',
#   'oldbalanceDest': 49161.0,
#   'newbalanceDest': 130747.56,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 29784.06,
#   'nameOrig': 'C925150995',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C920011586',
#   'oldbalanceDest': 63553.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 190445.51,
#   'nameOrig': 'C1760219993',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1360767589',
#   'oldbalanceDest': 203679.0,
#   'newbalanceDest': 2107965.39,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 57279.11,
#   'nameOrig': 'C1800649922',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C824009085',
#   'oldbalanceDest': 127206.9,
#   'newbalanceDest': 64106.18,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 112086.81,
#   'nameOrig': 'C403547747',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1531333864',
#   'oldbalanceDest': 292728.0,
#   'newbalanceDest': 55974.56,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 80311.89,
#   'nameOrig': 'C172215878',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C434091818',
# ...
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_IN',
#   'amount': 5221.77,
#   'nameOrig': 'C164714495',
#   'oldbalanceOrg': 1046.0,
#   'newbalanceOrig': 6267.77,
#   'nameDest': 'C317071334',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 139555.44,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 12256.66,
#   'nameOrig': 'C789982400',
#   'oldbalanceOrg': 20800.0,
#   'newbalanceOrig': 8543.34,
#   'nameDest': 'M1576277927',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8227.3,
#   'nameOrig': 'C2080643905',
#   'oldbalanceOrg': 6207.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M2137642385',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 527.15,
#   'nameOrig': 'C1627883152',
#   'oldbalanceOrg': 72421.0,
#   'newbalanceOrig': 71893.85,
#   'nameDest': 'M481553464',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 950.25,
#   'nameOrig': 'C1076966140',
#   'oldbalanceOrg': 204944.0,
#   'newbalanceOrig': 203993.75,
#   'nameDest': 'M1908781622',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 12728.46,
#   'nameOrig': 'C749443480',
#   'oldbalanceOrg': 83636.0,
#   'newbalanceOrig': 70907.54,
#   'nameDest': 'M796553753',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1002.96,
#   'nameOrig': 'C1721045976',
#   'oldbalanceOrg': 8325.0,
#   'newbalanceOrig': 7322.04,
#   'nameDest': 'M975001918',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6917.1,
#   'nameOrig': 'C1250582716',
#   'oldbalanceOrg': 13555.0,
#   'newbalanceOrig': 6637.9,
#   'nameDest': 'M907815246',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1977.17,
#   'nameOrig': 'C2019157894',
#   'oldbalanceOrg': 43619.0,
#   'newbalanceOrig': 41641.83,
#   'nameDest': 'M677217562',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9314.84,
#   'nameOrig': 'C827035437',
#   'oldbalanceOrg': 104536.0,
#   'newbalanceOrig': 95221.16,
#   'nameDest': 'M1716164115',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1157.05,
#   'nameOrig': 'C1360541835',
#   'oldbalanceOrg': 52867.0,
#   'newbalanceOrig': 51709.95,
#   'nameDest': 'M363397863',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 3766.99,
#   'nameOrig': 'C2021053848',
#   'oldbalanceOrg': 16600.0,
#   'newbalanceOrig': 12833.01,
#   'nameDest': 'C1123629720',
#   'oldbalanceDest': 146166.67,
#   'newbalanceDest': 46393.85,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3464.41,
#   'nameOrig': 'C1245593227',
#   'oldbalanceOrg': 5548.0,
#   'newbalanceOrig': 2083.59,
#   'nameDest': 'M1525844775',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 68662.06,
#   'nameOrig': 'C118555812',
#   'oldbalanceOrg': 2083.59,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1740000325',
#   'oldbalanceDest': 145843.39,
#   'newbalanceDest': 1363368.51,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 8679.29,
#   'nameOrig': 'C1233505227',
#   'oldbalanceOrg': 150592.0,
#   'newbalanceOrig': 141912.71,
#   'nameDest': 'C1877453512',
#   'oldbalanceDest': 21056.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 15266.05,
#   'nameOrig': 'C1928621590',
#   'oldbalanceOrg': 13679.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1016162524',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8348.75,
#   'nameOrig': 'C858423246',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1419125235',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8419.73,
#   'nameOrig': 'C88301993',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M841166421',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6688.74,
#   'nameOrig': 'C1377301456',
#   'oldbalanceOrg': 9207.0,
#   'newbalanceOrig': 2518.26,
#   'nameDest': 'M938199512',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1979.94,
#   'nameOrig': 'C691779749',
#   'oldbalanceOrg': 82034.0,
#   'newbalanceOrig': 80054.06,
#   'nameDest': 'M37841489',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9574.31,
#   'nameOrig': 'C1873121466',
#   'oldbalanceOrg': 52463.0,
#   'newbalanceOrig': 42888.69,
#   'nameDest': 'M115945887',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5287.68,
#   'nameOrig': 'C1927499639',
#   'oldbalanceOrg': 11424.0,
#   'newbalanceOrig': 6136.32,
#   'nameDest': 'M2079961240',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 10627.18,
#   'nameOrig': 'C949673757',
#   'oldbalanceOrg': 6136.32,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1999664216',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5809.78,
#   'nameOrig': 'C532677950',
#   'oldbalanceOrg': 99884.0,
#   'newbalanceOrig': 94074.22,
#   'nameDest': 'M688593710',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 411363.54,
#   'nameOrig': 'C1200048933',
#   'oldbalanceOrg': 39951.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1049817027',
#   'oldbalanceDest': 52170.0,
#   'newbalanceDest': 60738.03,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4086.5,
#   'nameOrig': 'C862025017',
#   'oldbalanceOrg': 0.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M739737502',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 19741.22,
#   'nameOrig': 'C1572127577',
#   'oldbalanceOrg': 81762.38,
#   'newbalanceOrig': 62021.17,
#   'nameDest': 'M546796969',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 5270.72,
#   'nameOrig': 'C417797183',
#   'oldbalanceOrg': 62021.17,
#   'newbalanceOrig': 56750.45,
#   'nameDest': 'M261845810',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_IN',
#   'amount': 55827.09,
#   'nameOrig': 'C1959708563',
#   'oldbalanceOrg': 9907.0,
#   'newbalanceOrig': 65734.09,
#   'nameDest': 'C1850180796',
#   'oldbalanceDest': 19873.0,
#   'newbalanceDest': 1268668.92,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 174068.82,
#   'nameOrig': 'C1877986974',
#   'oldbalanceOrg': 65734.09,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C33524623',
#   'oldbalanceDest': 1905641.8,
#   'newbalanceDest': 1517262.16,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 1277212.77,
#   'nameOrig': 'C1334405552',
#   'oldbalanceOrg': 1277212.77,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C431687661',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 1,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 1277212.77,
#   'nameOrig': 'C467632528',
#   'oldbalanceOrg': 1277212.77,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C716083600',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 2444985.19,
#   'isFraud': 1,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_IN',
#   'amount': 24105.5,
#   'nameOrig': 'C422522663',
#   'oldbalanceOrg': 144.0,
#   'newbalanceOrig': 24249.5,
#   'nameDest': 'C644345897',
#   'oldbalanceDest': 20875.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6854.06,
#   'nameOrig': 'C145066402',
#   'oldbalanceOrg': 19853.0,
#   'newbalanceOrig': 12998.94,
#   'nameDest': 'M207988207',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'CASH_OUT',
#   'amount': 111899.09,
#   'nameOrig': 'C1800500978',
#   'oldbalanceOrg': 12998.94,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1883840933',
#   'oldbalanceDest': 10026771.77,
#   'newbalanceDest': 16874643.09,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1231.79,
#   'nameOrig': 'C191310504',
#   'oldbalanceOrg': 20792.0,
#   'newbalanceOrig': 19560.21,
#   'nameDest': 'M799755007',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3380.1,
#   'nameOrig': 'C247515192',
#   'oldbalanceOrg': 19560.21,
#   'newbalanceOrig': 16180.11,
#   'nameDest': 'M1850137076',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 2869.65,
#   'nameOrig': 'C1556520190',
#   'oldbalanceOrg': 8768.0,
#   'newbalanceOrig': 5898.35,
#   'nameDest': 'C1664439369',
#   'oldbalanceDest': 15485.0,
#   'newbalanceDest': 5484.37,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1658.87,
#   'nameOrig': 'C701487403',
#   'oldbalanceOrg': 16543.0,
#   'newbalanceOrig': 14884.13,
#   'nameDest': 'M566641954',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 823.36,
#   'nameOrig': 'C2039984535',
#   'oldbalanceOrg': 14884.13,
#   'newbalanceOrig': 14060.77,
#   'nameDest': 'M299819831',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 7541.47,
#   'nameOrig': 'C1175418534',
#   'oldbalanceOrg': 14060.77,
#   'newbalanceOrig': 6519.3,
#   'nameDest': 'M1442038800',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 3635.93,
#   'nameOrig': 'C296541232',
#   'oldbalanceOrg': 106929.0,
#   'newbalanceOrig': 103293.07,
#   'nameDest': 'C288665596',
#   'oldbalanceDest': 95816.79,
#   'newbalanceDest': 8496.61,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1328.59,
#   'nameOrig': 'C1997357673',
#   'oldbalanceOrg': 14469.0,
#   'newbalanceOrig': 13140.41,
#   'nameDest': 'M1250603112',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 56145.85,
#   'nameOrig': 'C26357357',
#   'oldbalanceOrg': 21528.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1058634310',
#   'oldbalanceDest': 5075.0,
#   'newbalanceDest': 33008.44,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 973.18,
#   'nameOrig': 'C1990733619',
#   'oldbalanceOrg': 10762.0,
#   'newbalanceOrig': 9788.82,
#   'nameDest': 'M1806378373',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 619.24,
#   'nameOrig': 'C1958592872',
#   'oldbalanceOrg': 31960.0,
#   'newbalanceOrig': 31340.76,
#   'nameDest': 'M1682733268',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 300.41,
#   'nameOrig': 'C1395262169',
#   'oldbalanceOrg': 39167.0,
#   'newbalanceOrig': 38866.59,
#   'nameDest': 'C736709391',
#   'oldbalanceDest': 48749.55,
#   'newbalanceDest': 46820.71,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'TRANSFER',
#   'amount': 700967.19,
#   'nameOrig': 'C1629454900',
#   'oldbalanceOrg': 15383.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'C1060830840',
#   'oldbalanceDest': 50767.43,
#   'newbalanceDest': 130747.56,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8354.27,
#   'nameOrig': 'C2075372030',
#   'oldbalanceOrg': 5611.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M2092885124',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'DEBIT',
#   'amount': 5423.28,
#   'nameOrig': 'C2139168000',
#   'oldbalanceOrg': 20281.0,
#   'newbalanceOrig': 14857.72,
#   'nameDest': 'C367746789',
#   'oldbalanceDest': 11523.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 708.59,
#   'nameOrig': 'C1653751526',
#   'oldbalanceOrg': 14857.72,
#   'newbalanceOrig': 14149.13,
#   'nameDest': 'M67671827',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 8358.81,
#   'nameOrig': 'C253348306',
#   'oldbalanceOrg': 3467.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M2013768748',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2245.62,
#   'nameOrig': 'C194107588',
#   'oldbalanceOrg': 30910.0,
#   'newbalanceOrig': 28664.38,
#   'nameDest': 'M1264674474',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 4593.59,
#   'nameOrig': 'C175595853',
#   'oldbalanceOrg': 78282.0,
#   'newbalanceOrig': 73688.41,
#   'nameDest': 'M1339345635',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 399.66,
#   'nameOrig': 'C1241938981',
#   'oldbalanceOrg': 153760.0,
#   'newbalanceOrig': 153360.34,
#   'nameDest': 'M168957945',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 1617.9,
#   'nameOrig': 'C1004430079',
#   'oldbalanceOrg': 507865.0,
#   'newbalanceOrig': 506247.1,
#   'nameDest': 'M1379148981',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2167.26,
#   'nameOrig': 'C732597634',
#   'oldbalanceOrg': 13669.0,
#   'newbalanceOrig': 11501.74,
#   'nameDest': 'M832432849',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 9738.95,
#   'nameOrig': 'C2031927175',
#   'oldbalanceOrg': 289748.0,
#   'newbalanceOrig': 280009.05,
#   'nameDest': 'M176041373',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 3396.25,
#   'nameOrig': 'C1967617997',
#   'oldbalanceOrg': 18524.0,
#   'newbalanceOrig': 15127.75,
#   'nameDest': 'M726843606',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 6780.78,
#   'nameOrig': 'C925803196',
#   'oldbalanceOrg': 52640.0,
#   'newbalanceOrig': 45859.22,
#   'nameDest': 'M1288135425',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  {'step': 1,
#   'type': 'PAYMENT',
#   'amount': 2284.54,
#   'nameOrig': 'C49318987',
#   'oldbalanceOrg': 539.0,
#   'newbalanceOrig': 0.0,
#   'nameDest': 'M1058650291',
#   'oldbalanceDest': 0.0,
#   'newbalanceDest': 0.0,
#   'isFraud': 0,
#   'isFlaggedFraud': 0},
#  ...]
